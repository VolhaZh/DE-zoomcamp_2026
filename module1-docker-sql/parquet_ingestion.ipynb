# %%
import pandas as pd
from sqlalchemy import create_engine
from time import time
import pyarrow.parquet as pq

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
chunksize = 100000
parquet_file = pq.ParquetFile('green_tripdata_2025-11.parquet')

# %%
print(f"Rows count: {parquet_file.metadata.num_rows:,}")
print(f"Count of row groups: {parquet_file.num_row_groups}")
print(f"Schema: {parquet_file.schema}")
# Out:
# Rows count: 46,912
# Count of row groups: 1
# Schema: <pyarrow._parquet.ParquetSchema object at 0x10dec4500>
# required group field_id=-1 schema {
#   optional int32 field_id=-1 VendorID;
#   optional int64 field_id=-1 lpep_pickup_datetime (Timestamp(isAdjustedToUTC=false, timeUnit=microseconds, is_from_converted_type=false, force_set_converted_type=false));
#   optional int64 field_id=-1 lpep_dropoff_datetime (Timestamp(isAdjustedToUTC=false, timeUnit=microseconds, is_from_converted_type=false, force_set_converted_type=false));
#   optional binary field_id=-1 store_and_fwd_flag (String);
#   optional int64 field_id=-1 RatecodeID;
#   optional int32 field_id=-1 PULocationID;
#   optional int32 field_id=-1 DOLocationID;
#   optional int64 field_id=-1 passenger_count;
#   optional double field_id=-1 trip_distance;
#   optional double field_id=-1 fare_amount;
#   optional double field_id=-1 extra;
#   optional double field_id=-1 mta_tax;
#   optional double field_id=-1 tip_amount;
#   optional double field_id=-1 tolls_amount;
#   optional double field_id=-1 ehail_fee;
#   optional double field_id=-1 improvement_surcharge;
#   optional double field_id=-1 total_amount;
#   optional int64 field_id=-1 payment_type;
#   optional int64 field_id=-1 trip_type;
#   optional double field_id=-1 congestion_surcharge;
#   optional double field_id=-1 cbd_congestion_fee;
# }

# %%
count = 0
full_size = 0
while True:
    try:
        t_start = time()
        count += 1
        # df = next(df_iter)
        for batch in parquet_file.iter_batches(batch_size=chunksize):
            df = batch.to_pandas()
            full_size += len(df)
            
            df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
            df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        
            df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
            t_end = time()
            print(f'{count}. insertanother chunk..., took %.3f second' % (t_end - t_start))
    except StopIteration:
        print(f'Insertion complited. All {full_size} lines inserted into the postgres database!')
        break
# Out:
# 1. insertanother chunk..., took 3.526 second
# 2. insertanother chunk..., took 3.384 second
# 3. insertanother chunk..., took 3.307 second
# 4. insertanother chunk..., took 3.267 second
# 5. insertanother chunk..., took 3.271 second
# 6. insertanother chunk..., took 3.256 second
# 7. insertanother chunk..., took 3.232 second
# 8. insertanother chunk..., took 3.281 second
# 9. insertanother chunk..., took 3.333 second
# 10. insertanother chunk..., took 3.273 second
# 11. insertanother chunk..., took 3.233 second
# 12. insertanother chunk..., took 3.268 second
# 13. insertanother chunk..., took 3.227 second
# 14. insertanother chunk..., took 3.270 second
# 15. insertanother chunk..., took 3.251 second
# 16. insertanother chunk..., took 3.244 second
# 17. insertanother chunk..., took 3.230 second
# 18. insertanother chunk..., took 3.235 second
# 19. insertanother chunk..., took 3.196 second
# 20. insertanother chunk..., took 3.288 second
# 21. insertanother chunk..., took 3.251 second
# 22. insertanother chunk..., took 3.199 second
# 23. insertanother chunk..., took 3.244 second
# 24. insertanother chunk..., took 3.197 second
# 25. insertanother chunk..., took 3.432 second
# 26. insertanother chunk..., took 3.330 second
# 27. insertanother chunk..., took 3.328 second
# 28. insertanother chunk..., took 3.365 second
# 29. insertanother chunk..., took 3.252 second
# 30. insertanother chunk..., took 3.270 second
# 31. insertanother chunk..., took 3.249 second
# 32. insertanother chunk..., took 3.268 second
# 33. insertanother chunk..., took 3.275 second
# 34. insertanother chunk..., took 3.208 second
# 35. insertanother chunk..., took 3.258 second
# 36. insertanother chunk..., took 3.220 second
# 37. insertanother chunk..., took 3.233 second
# 38. insertanother chunk..., took 3.229 second
# 39. insertanother chunk..., took 3.272 second
# 40. insertanother chunk..., took 3.226 second
# 41. insertanother chunk..., took 3.304 second
# 42. insertanother chunk..., took 3.294 second
# 43. insertanother chunk..., took 3.243 second
# 44. insertanother chunk..., took 3.241 second
# 45. insertanother chunk..., took 3.245 second
# 46. insertanother chunk..., took 3.240 second
# 47. insertanother chunk..., took 3.224 second
# 48. insertanother chunk..., took 3.179 second
# 49. insertanother chunk..., took 3.249 second
# 50. insertanother chunk..., took 3.201 second
# 51. insertanother chunk..., took 3.261 second
# 52. insertanother chunk..., took 3.258 second
# 53. insertanother chunk..., took 3.282 second
# 54. insertanother chunk..., took 3.293 second
# 55. insertanother chunk..., took 3.233 second
# 56. insertanother chunk..., took 3.312 second
# 57. insertanother chunk..., took 3.242 second
# 58. insertanother chunk..., took 3.253 second
# 59. insertanother chunk..., took 3.200 second
# 60. insertanother chunk..., took 3.276 second
# 61. insertanother chunk..., took 3.250 second
# 62. insertanother chunk..., took 3.273 second
# 63. insertanother chunk..., took 3.245 second
# 64. insertanother chunk..., took 3.319 second
# 65. insertanother chunk..., took 3.227 second
# 66. insertanother chunk..., took 3.338 second
# 67. insertanother chunk..., took 3.260 second
# 68. insertanother chunk..., took 3.245 second
# 69. insertanother chunk..., took 3.221 second
# 70. insertanother chunk..., took 3.287 second
# 71. insertanother chunk..., took 3.228 second
# 72. insertanother chunk..., took 3.290 second
# 73. insertanother chunk..., took 3.218 second
# 74. insertanother chunk..., took 3.278 second
# 75. insertanother chunk..., took 3.261 second
# 76. insertanother chunk..., took 3.285 second
# 77. insertanother chunk..., took 3.292 second
# 78. insertanother chunk..., took 3.292 second
# 79. insertanother chunk..., took 3.261 second
# 80. insertanother chunk..., took 3.289 second
# 81. insertanother chunk..., took 3.253 second
# 82. insertanother chunk..., took 3.343 second
# 83. insertanother chunk..., took 3.239 second
# 84. insertanother chunk..., took 3.303 second
# 85. insertanother chunk..., took 3.303 second
# 86. insertanother chunk..., took 3.346 second
# 87. insertanother chunk..., took 3.303 second
# 88. insertanother chunk..., took 3.272 second
# 89. insertanother chunk..., took 3.278 second
# 90. insertanother chunk..., took 3.306 second
# 91. insertanother chunk..., took 3.232 second
# 92. insertanother chunk..., took 3.284 second
# 93. insertanother chunk..., took 3.461 second
# 94. insertanother chunk..., took 3.437 second
# 95. insertanother chunk..., took 3.263 second
# 96. insertanother chunk..., took 3.300 second
# 97. insertanother chunk..., took 3.288 second
# 98. insertanother chunk..., took 3.243 second
# 99. insertanother chunk..., took 3.339 second
# 100. insertanother chunk..., took 3.260 second
# 101. insertanother chunk..., took 3.399 second
# 102. insertanother chunk..., took 3.235 second
# 103. insertanother chunk..., took 3.285 second
# 104. insertanother chunk..., took 3.298 second
# 105. insertanother chunk..., took 3.292 second
# 106. insertanother chunk..., took 3.229 second
# 107. insertanother chunk..., took 3.296 second
# 108. insertanother chunk..., took 3.190 second
# 109. insertanother chunk..., took 3.306 second
# 110. insertanother chunk..., took 3.297 second
# 111. insertanother chunk..., took 3.400 second
# 112. insertanother chunk..., took 3.269 second
# 113. insertanother chunk..., took 3.280 second
# 114. insertanother chunk..., took 3.304 second
# 115. insertanother chunk..., took 3.253 second
# 116. insertanother chunk..., took 3.261 second
# 117. insertanother chunk..., took 3.407 second
# 118. insertanother chunk..., took 3.276 second
# 119. insertanother chunk..., took 3.329 second
# 120. insertanother chunk..., took 3.297 second
# 121. insertanother chunk..., took 3.288 second
# 122. insertanother chunk..., took 3.287 second
# 123. insertanother chunk..., took 3.284 second
# 124. insertanother chunk..., took 3.262 second
# 125. insertanother chunk..., took 3.257 second
# 126. insertanother chunk..., took 3.305 second
# 127. insertanother chunk..., took 3.309 second
# 128. insertanother chunk..., took 3.238 second
# 129. insertanother chunk..., took 3.279 second
# 130. insertanother chunk..., took 3.263 second
# 131. insertanother chunk..., took 3.243 second
# 132. insertanother chunk..., took 3.278 second
# 133. insertanother chunk..., took 3.249 second
# 134. insertanother chunk..., took 3.215 second
# 135. insertanother chunk..., took 3.304 second
# 136. insertanother chunk..., took 3.285 second
# 137. insertanother chunk..., took 3.284 second
# 138. insertanother chunk..., took 3.300 second
# 139. insertanother chunk..., took 3.257 second
# 140. insertanother chunk..., took 3.223 second
# 141. insertanother chunk..., took 3.281 second
# 142. insertanother chunk..., took 3.242 second
# 143. insertanother chunk..., took 3.228 second
# 144. insertanother chunk..., took 3.290 second
# 145. insertanother chunk..., took 3.210 second
# 146. insertanother chunk..., took 3.295 second
# 147. insertanother chunk..., took 3.249 second
# 148. insertanother chunk..., took 3.272 second
# 149. insertanother chunk..., took 3.290 second
# 150. insertanother chunk..., took 3.298 second
# 151. insertanother chunk..., took 3.249 second
# 152. insertanother chunk..., took 3.246 second
# 153. insertanother chunk..., took 3.301 second
# 154. insertanother chunk..., took 3.295 second
# 155. insertanother chunk..., took 3.280 second
# 156. insertanother chunk..., took 3.334 second
# 157. insertanother chunk..., took 3.329 second
# 158. insertanother chunk..., took 3.490 second
# 159. insertanother chunk..., took 3.309 second
# 160. insertanother chunk..., took 3.270 second
# 161. insertanother chunk..., took 3.265 second
# 162. insertanother chunk..., took 3.363 second
# 163. insertanother chunk..., took 3.314 second
# 164. insertanother chunk..., took 3.269 second
# 165. insertanother chunk..., took 3.275 second
# 166. insertanother chunk..., took 3.262 second
# 167. insertanother chunk..., took 3.246 second
# 168. insertanother chunk..., took 3.229 second
# 169. insertanother chunk..., took 3.277 second
# 170. insertanother chunk..., took 3.302 second
# 171. insertanother chunk..., took 3.238 second
# 172. insertanother chunk..., took 3.243 second
# 173. insertanother chunk..., took 3.307 second
# 174. insertanother chunk..., took 3.319 second
# 175. insertanother chunk..., took 3.226 second
# 176. insertanother chunk..., took 3.272 second
# 177. insertanother chunk..., took 3.310 second
# 178. insertanother chunk..., took 3.238 second
# 179. insertanother chunk..., took 3.308 second
# 180. insertanother chunk..., took 3.265 second
# 181. insertanother chunk..., took 3.242 second
# 182. insertanother chunk..., took 3.220 second
# 183. insertanother chunk..., took 3.400 second
# 184. insertanother chunk..., took 3.302 second
# 185. insertanother chunk..., took 3.348 second
# 186. insertanother chunk..., took 3.307 second
# 187. insertanother chunk..., took 3.263 second
# 188. insertanother chunk..., took 3.283 second
# 189. insertanother chunk..., took 3.306 second
# 190. insertanother chunk..., took 3.293 second
# 191. insertanother chunk..., took 3.431 second
# 192. insertanother chunk..., took 3.654 second
# 193. insertanother chunk..., took 3.289 second
# 194. insertanother chunk..., took 3.280 second
# 195. insertanother chunk..., took 3.322 second
# 196. insertanother chunk..., took 3.314 second
# 197. insertanother chunk..., took 3.272 second
# 198. insertanother chunk..., took 3.437 second
# 199. insertanother chunk..., took 3.275 second
# 200. insertanother chunk..., took 3.272 second
# 201. insertanother chunk..., took 3.274 second
# 202. insertanother chunk..., took 3.533 second
# 203. insertanother chunk..., took 3.371 second
# 204. insertanother chunk..., took 3.329 second
# 205. insertanother chunk..., took 3.286 second
# 206. insertanother chunk..., took 3.233 second
# 207. insertanother chunk..., took 3.414 second
# 208. insertanother chunk..., took 3.552 second
# 209. insertanother chunk..., took 3.297 second
# 210. insertanother chunk..., took 3.275 second
# 211. insertanother chunk..., took 3.366 second
# 212. insertanother chunk..., took 3.296 second
# 213. insertanother chunk..., took 3.283 second
# 214. insertanother chunk..., took 3.258 second
# 215. insertanother chunk..., took 3.261 second
# 216. insertanother chunk..., took 3.257 second
# 217. insertanother chunk..., took 3.224 second
# 218. insertanother chunk..., took 3.328 second
# 219. insertanother chunk..., took 3.283 second
# 220. insertanother chunk..., took 3.376 second
# 221. insertanother chunk..., took 3.287 second
# 222. insertanother chunk..., took 3.310 second
# 223. insertanother chunk..., took 3.335 second
# 224. insertanother chunk..., took 3.252 second
# 225. insertanother chunk..., took 3.230 second
# 226. insertanother chunk..., took 3.320 second
# 227. insertanother chunk..., took 3.273 second
# 228. insertanother chunk..., took 3.293 second
# 229. insertanother chunk..., took 3.242 second
# 230. insertanother chunk..., took 3.290 second
# 231. insertanother chunk..., took 3.266 second
# 232. insertanother chunk..., took 3.249 second
# 233. insertanother chunk..., took 3.320 second
# 234. insertanother chunk..., took 3.297 second
# 235. insertanother chunk..., took 3.329 second
# 236. insertanother chunk..., took 3.249 second
# 237. insertanother chunk..., took 3.237 second
# 238. insertanother chunk..., took 3.238 second
# 239. insertanother chunk..., took 3.323 second
# 240. insertanother chunk..., took 3.288 second
# 241. insertanother chunk..., took 3.282 second
# 242. insertanother chunk..., took 3.282 second
# 243. insertanother chunk..., took 3.257 second
# 244. insertanother chunk..., took 3.269 second
# 245. insertanother chunk..., took 3.637 second
# 246. insertanother chunk..., took 3.360 second
# 247. insertanother chunk..., took 3.397 second
# 248. insertanother chunk..., took 3.356 second
# 249. insertanother chunk..., took 3.351 second
# 250. insertanother chunk..., took 3.322 second
# 251. insertanother chunk..., took 3.421 second
# 252. insertanother chunk..., took 3.386 second
# 253. insertanother chunk..., took 3.816 second
# 254. insertanother chunk..., took 3.463 second
# 255. insertanother chunk..., took 3.405 second
# 256. insertanother chunk..., took 3.355 second
# 257. insertanother chunk..., took 3.602 second
# 258. insertanother chunk..., took 3.313 second
# 259. insertanother chunk..., took 3.262 second
# 260. insertanother chunk..., took 3.394 second
# 261. insertanother chunk..., took 3.273 second
# 262. insertanother chunk..., took 3.349 second
# 263. insertanother chunk..., took 3.507 second
# 264. insertanother chunk..., took 3.461 second
# 265. insertanother chunk..., took 3.450 second
# 266. insertanother chunk..., took 3.327 second
# 267. insertanother chunk..., took 3.384 second
# 268. insertanother chunk..., took 3.287 second
# 269. insertanother chunk..., took 3.319 second
# 270. insertanother chunk..., took 3.310 second
# 271. insertanother chunk..., took 3.344 second
# 272. insertanother chunk..., took 3.305 second
# 273. insertanother chunk..., took 3.204 second
# 274. insertanother chunk..., took 3.411 second
# 275. insertanother chunk..., took 3.304 second
# 276. insertanother chunk..., took 3.312 second
# 277. insertanother chunk..., took 3.335 second
# 278. insertanother chunk..., took 3.325 second
# 279. insertanother chunk..., took 3.293 second
# 280. insertanother chunk..., took 3.302 second
# 281. insertanother chunk..., took 3.335 second
# 282. insertanother chunk..., took 3.491 second
# 283. insertanother chunk..., took 3.353 second
# 284. insertanother chunk..., took 3.309 second
# 285. insertanother chunk..., took 3.384 second
# 286. insertanother chunk..., took 3.305 second
# 287. insertanother chunk..., took 3.279 second
# 288. insertanother chunk..., took 3.367 second
# 289. insertanother chunk..., took 3.617 second
# 290. insertanother chunk..., took 3.555 second
# 291. insertanother chunk..., took 3.339 second
# 292. insertanother chunk..., took 3.544 second
# 293. insertanother chunk..., took 3.361 second
# 294. insertanother chunk..., took 3.366 second
# 295. insertanother chunk..., took 3.518 second
# 296. insertanother chunk..., took 3.256 second
# 297. insertanother chunk..., took 3.701 second
# 298. insertanother chunk..., took 3.389 second
# 299. insertanother chunk..., took 3.452 second
# 300. insertanother chunk..., took 3.514 second
# 301. insertanother chunk..., took 3.369 second
# 302. insertanother chunk..., took 3.312 second
# 303. insertanother chunk..., took 3.316 second
# 304. insertanother chunk..., took 3.314 second
# 305. insertanother chunk..., took 3.313 second
# 306. insertanother chunk..., took 3.332 second
# 307. insertanother chunk..., took 3.339 second
# 308. insertanother chunk..., took 3.326 second
# 309. insertanother chunk..., took 3.471 second
# 310. insertanother chunk..., took 3.276 second
# 311. insertanother chunk..., took 3.357 second
# 312. insertanother chunk..., took 3.309 second
# 313. insertanother chunk..., took 3.305 second
# 314. insertanother chunk..., took 3.543 second
# 315. insertanother chunk..., took 3.358 second
# 316. insertanother chunk..., took 3.458 second
# 317. insertanother chunk..., took 3.315 second
# 318. insertanother chunk..., took 3.445 second
# 319. insertanother chunk..., took 3.270 second
# 320. insertanother chunk..., took 3.488 second
# 321. insertanother chunk..., took 3.430 second
# 322. insertanother chunk..., took 3.233 second
# 323. insertanother chunk..., took 3.437 second
# 324. insertanother chunk..., took 3.323 second
# 325. insertanother chunk..., took 3.360 second
# 326. insertanother chunk..., took 3.256 second
# 327. insertanother chunk..., took 3.401 second
# 328. insertanother chunk..., took 3.371 second
# 329. insertanother chunk..., took 3.247 second
# 330. insertanother chunk..., took 3.391 second
# 331. insertanother chunk..., took 3.354 second
# 332. insertanother chunk..., took 3.327 second
# 333. insertanother chunk..., took 3.338 second
# 334. insertanother chunk..., took 3.347 second
# 335. insertanother chunk..., took 3.472 second
# 336. insertanother chunk..., took 3.259 second
# 337. insertanother chunk..., took 3.829 second
# 338. insertanother chunk..., took 3.861 second
# 339. insertanother chunk..., took 3.394 second
# 340. insertanother chunk..., took 3.424 second
# 341. insertanother chunk..., took 3.242 second
# 342. insertanother chunk..., took 3.464 second
# 343. insertanother chunk..., took 3.306 second
# 344. insertanother chunk..., took 3.309 second
# 345. insertanother chunk..., took 3.264 second
# 346. insertanother chunk..., took 3.335 second
# 347. insertanother chunk..., took 3.568 second
# 348. insertanother chunk..., took 3.329 second
# 349. insertanother chunk..., took 3.409 second
# 350. insertanother chunk..., took 3.425 second
# 351. insertanother chunk..., took 3.348 second
# 352. insertanother chunk..., took 3.332 second
# 353. insertanother chunk..., took 3.281 second
# 354. insertanother chunk..., took 3.300 second
# 355. insertanother chunk..., took 3.322 second
# 356. insertanother chunk..., took 3.406 second
# 357. insertanother chunk..., took 3.246 second
# 358. insertanother chunk..., took 3.305 second
# 359. insertanother chunk..., took 3.298 second
# 360. insertanother chunk..., took 3.400 second
# 361. insertanother chunk..., took 3.224 second
# 362. insertanother chunk..., took 3.440 second
# 363. insertanother chunk..., took 3.290 second
# 364. insertanother chunk..., took 3.403 second
# 365. insertanother chunk..., took 3.381 second
# 366. insertanother chunk..., took 3.451 second
# 367. insertanother chunk..., took 3.404 second
# 368. insertanother chunk..., took 3.590 second
# 369. insertanother chunk..., took 3.586 second
# 370. insertanother chunk..., took 3.475 second
# 371. insertanother chunk..., took 3.745 second
# 372. insertanother chunk..., took 3.364 second
# 373. insertanother chunk..., took 3.338 second
# 374. insertanother chunk..., took 3.470 second
# 375. insertanother chunk..., took 3.426 second
# 376. insertanother chunk..., took 3.231 second
# 377. insertanother chunk..., took 3.299 second
# 378. insertanother chunk..., took 3.305 second
# 379. insertanother chunk..., took 3.304 second
# 380. insertanother chunk..., took 3.392 second
# 381. insertanother chunk..., took 3.341 second
# 382. insertanother chunk..., took 3.316 second
# 383. insertanother chunk..., took 3.311 second
# 384. insertanother chunk..., took 3.334 second
# 385. insertanother chunk..., took 3.350 second
# 386. insertanother chunk..., took 3.787 second
# 387. insertanother chunk..., took 3.408 second
# 388. insertanother chunk..., took 3.454 second
# 389. insertanother chunk..., took 3.359 second
# 390. insertanother chunk..., took 3.322 second
# 391. insertanother chunk..., took 3.334 second
# 392. insertanother chunk..., took 3.350 second
# 393. insertanother chunk..., took 3.395 second
# 394. insertanother chunk..., took 3.337 second
# 395. insertanother chunk..., took 3.414 second
# 396. insertanother chunk..., took 3.311 second
# 397. insertanother chunk..., took 3.400 second
# 398. insertanother chunk..., took 3.278 second
# 399. insertanother chunk..., took 3.364 second
# 400. insertanother chunk..., took 3.343 second
# 401. insertanother chunk..., took 3.379 second
# 402. insertanother chunk..., took 5.379 second
# 403. insertanother chunk..., took 3.642 second
# 404. insertanother chunk..., took 3.338 second
# 405. insertanother chunk..., took 3.459 second
# 406. insertanother chunk..., took 3.402 second
# 407. insertanother chunk..., took 3.358 second
# 408. insertanother chunk..., took 3.303 second
# 409. insertanother chunk..., took 3.492 second
# 410. insertanother chunk..., took 3.500 second
# 411. insertanother chunk..., took 3.527 second
# 412. insertanother chunk..., took 3.339 second
# 413. insertanother chunk..., took 3.363 second
# 414. insertanother chunk..., took 3.365 second
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[16], line 15
#      12 df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#      13 df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
# ---> 15 df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
#      16 t_end = time()
#      17 print(f'{count}. insertanother chunk..., took %.3f second' % (t_end - t_start))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/sql.py:1548, in SQLDatabase.__exit__(self, *args)
#    1546 def __exit__(self, *args) -> None:
#    1547     if not self.returns_generator:
# -> 1548         self.exit_stack.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/contextlib.py:533, in ExitStack.close(self)
#     531 def close(self):
#     532     """Immediately unwind the context stack."""
# --> 533     self.__exit__(None, None, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/contextlib.py:525, in ExitStack.__exit__(self, *exc_details)
#     521 try:
#     522     # bare "raise exc_details[1]" replaces our carefully
#     523     # set-up context
#     524     fixed_ctx = exc_details[1].__context__
# --> 525     raise exc_details[1]
#     526 except BaseException:
#     527     exc_details[1].__context__ = fixed_ctx
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/contextlib.py:510, in ExitStack.__exit__(self, *exc_details)
#     508 assert is_sync
#     509 try:
# --> 510     if cb(*exc_details):
#     511         suppressed_exc = True
#     512         pending_raise = False
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/util.py:149, in TransactionalContext.__exit__(self, type_, value, traceback)
#     147     with util.safe_reraise():
#     148         if self._rollback_can_be_called():
# --> 149             self.rollback()
#     150 finally:
#     151     if not out_of_band_exit:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/util.py:145, in TransactionalContext.__exit__(self, type_, value, traceback)
#     143 if type_ is None and self._transaction_is_active():
#     144     try:
# --> 145         self.commit()
#     146     except:
#     147         with util.safe_reraise():
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2629, in Transaction.commit(self)
#    2613 """Commit this :class:`.Transaction`.
#    2614
#    2615 The implementation of this may vary based on the type of transaction in
#    (...)
#    2626
#    2627 """
#    2628 try:
# -> 2629     self._do_commit()
#    2630 finally:
#    2631     assert not self.is_active
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2734, in RootTransaction._do_commit(self)
#    2731 assert self.connection._transaction is self
#    2733 try:
# -> 2734     self._connection_commit_impl()
#    2735 finally:
#    2736     # whether or not commit succeeds, cancel any
#    2737     # nested transactions, make this transaction "inactive"
#    2738     # and remove it as a reset agent
#    2739     if self.connection._nested_transaction:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2705, in RootTransaction._connection_commit_impl(self)
#    2704 def _connection_commit_impl(self) -> None:
# -> 2705     self.connection._commit_impl()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1144, in Connection._commit_impl(self)
#    1142     self.engine.dialect.do_commit(self.connection)
#    1143 except BaseException as e:
# -> 1144     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353     else:
#    2354         assert exc_info[1] is not None
# -> 2355         raise exc_info[1].with_traceback(exc_info[2])
#    2356 finally:
#    2357     del self._reentrant_error
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1142, in Connection._commit_impl(self)
#    1140         self._log_info("COMMIT")
#    1141 try:
# -> 1142     self.engine.dialect.do_commit(self.connection)
#    1143 except BaseException as e:
#    1144     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:584, in Connection.connection(self)
#     582 if self._dbapi_connection is None:
#     583     try:
# --> 584         return self._revalidate_connection()
#     585     except (exc.PendingRollbackError, exc.ResourceClosedError):
#     586         raise
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:676, in Connection._revalidate_connection(self)
#     674 if self.__can_reconnect and self.invalidated:
#     675     if self._transaction is not None:
# --> 676         self._invalid_transaction()
#     677     self._dbapi_connection = self.engine.raw_connection()
#     678     return self._dbapi_connection
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sqlalchemy/engine/base.py:666, in Connection._invalid_transaction(self)
#     665 def _invalid_transaction(self) -> NoReturn:
# --> 666     raise exc.PendingRollbackError(
#     667         "Can't reconnect until invalid %stransaction is rolled "
#     668         "back.  Please rollback() fully before proceeding"
#     669         % ("savepoint " if self._nested_transaction is not None else ""),
#     670         code="8s2b",
#     671     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)

# %%
df_csv = pd.read_csv("taxi_zone_lookup.csv")

# %%
df_csv.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_csv.to_sql(name='taxi_zone_lookup', con=engine, if_exists='append')
# Out:
# 265

# %%
select "PULocationID", "Zone", sum(total_amount) 
from dedupl d join taxi_zone_lookup t ON t."LocationID" = d."PULocationID"
where d.lpep_pickup_datetime >= '2025-11-18 00:00:00'
  AND d.lpep_pickup_datetime < '2025-11-19 00:00:00'
group by "PULocationID", "Zone"
order by 3 desc limit 1;


select tip_amount, "DOLocationID", t."Zone"
from dedupl d join taxi_zone_lookup t ON t."LocationID" = d."DOLocationID"
where d."PULocationID" = (
    select z."LocationID" 
    from taxi_zone_lookup z
    where z."Zone" = 'East Harlem North'
)
order by 1 desc limit 1;

SELECT zdo."Zone" dropoff, tip_amount 
FROM trip t JOIN zones AS zpu ON t.PULocationID = zpu.LocationID 
JOIN zones AS zdo ON t.DOLocationID = zdo.LocationID 
WHERE zpu."Zone" = 'East Harlem North' 
ORDER BY tip_amount DESC LIMIT 1;
┌────────────────┬────────────┐
│    dropoff     │ tip_amount │
│    varchar     │   double   │
├────────────────┼────────────┤
│ Yorkville West │   81.89    │
└────────────────┴────────────┘
